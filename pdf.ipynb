# %%
# %pip install ipython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install fpdf2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import fpdf
print(fpdf.__version__)  # Doit être 2.x
# Out:
# 2.8.3

# %%
from features_api import assistant_pedagogique
from pretraitement_obj_spe import nettoyer_objectifs_specifiques

nom_cours = "Méthodes d'analyse et de spécification"
niveau = "Licence 3"
public = "Étudiants en IA"
objectif_general = "Au terme du cours, l'apprenant·e sera capable de produire un dossier complet de spécification logicielle, intégrant une modélisation précise des besoins fonctionnels et techniques à l'aide de diagrammes UML (cas d'utilisation, classes, séquence), une conception architecturale justifiée suivant les bonnes pratiques du génie logiciel, une validation critique des modèles produits à travers des méthodes de vérification et des tests, et une documentation professionnelle et une présentation claire des choix de conception."
objectifs_specifiques_brut = """
Au terme de ce cours, l’apprenant·e sera en mesure de :
1.	Identifier et formaliser les besoins utilisateurs à l’aide de techniques.
2.	Modéliser des systèmes d’information avec UML (Diagrammes de cas d’utilisation, classes, séquence, activité, etc.).
3.	Concevoir une architecture logicielle en choisissant des méthodologies adaptées (MERISE, Agile, etc.).
4.	Valider les modèles produits via des techniques de vérification (revues, tests de scénarios).
5.	Implémenter des prototypes fonctionnels en suivant les spécifications techniques.
6.	Collaborer efficacement en équipe.
7.	Présenter oralement et par écrit les résultats d’analyse et de conception.
"""

objectifs_specifiques = nettoyer_objectifs_specifiques(objectif_general, objectifs_specifiques_brut)

rapport = assistant_pedagogique(nom_cours, niveau, public, objectif_general, objectifs_specifiques)

print(rapport)
# Out:
# INFO:features_api:Début de l'analyse pédagogique pour le cours : Méthodes d'analyse et de spécification
# INFO:features_api:Étape 1 : Classification selon Bloom
# 2025-06-05 00:21:17.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-05 00:21:17.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# INFO:features_api:Appel de l'API Mistral...
# INFO:httpx:HTTP Request: POST https://api.mistral.ai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:features_api:Réponse reçue avec succès.
# INFO:features_api:Étape 2 : Évaluation des objectifs
# 2025-06-05 00:22:13.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-05 00:22:13.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# INFO:features_api:Appel de l'API Mistral...
# ...

# %% [markdown]
# {'informations_cours': "\n        **Cours :** Résolution de problèmes par la\xa0recherche\n        **Niveau :** Licence 3\n        **Public cible :** Étudiants en IA \n        **Objectif général :** \n          Au terme du cours Techniques de résolution de problèmes par la recherche, l’apprenant.e sera capable de produire un prototype de résolution automatique d’un problème par la recherche, intégrant la modélisation du problème, le choix d’un algorithme ou d’une heuristique pertinent.e, son implémentation, et l’évaluation de sa performance dans un cas d’usage concret.\n        **Objectifs specifiques :** \n          ['Au terme du cours techniques de résolution de problèmes par la recherche, L’apprenant.e sera capable de formuler un problème complexe sous une forme exploitable  par des algorithmes de recherche (graphe d’états, espace de recherche, contraintes) en identifiant les états, les actions, les objectifs et les contraintes', 'Au terme du cours techniques de résolution de problèmes par la recherche, L’apprenant.e sera capable de justifier le choix d’une stratégie de recherche (non informée ou informée) à partir d’au moins deux critères : structure du problème, contraintes de temps ou d’espace, optimalité de la solution, dans une grille comparative de plusieurs approches', 'Au terme du cours techniques de résolution de problèmes par la recherche, L’apprenant.e sera capable de implémenter une ou plusieurs techniques de recherche algorithmique ou heuristique (recherche en largeur, profondeur, A*, etc.) dans un environnement de programmation, en respectant les bonnes pratiques de développement (lisibilité, modularité, tests', 'Au terme du cours techniques de résolution de problèmes par la recherche, L’apprenant.e sera capable de analyser la performance des algorithmes utilisés  en évaluant leur efficacité à l’aide d’indicateurs pertinents (coût de la solution, nombre d’itérations, mémoire utilisée) dans des contextes variés (réels ou simulés)', 'Au terme du cours techniques de résolution de problèmes par la recherche, L’apprenant.e sera capable de collaborer à la résolution d’un problème par la recherche en équipe, en respectant les rôles définis, en documentant les décisions prises et en gérant les tâches avec un outil de planification de projet (ex. Trello, GitHub Projects)', 'Au terme du cours techniques de résolution de problèmes par la recherche, L’apprenant.e sera capable de présenter de manière structurée les démarches, résultats et choix effectués pour résoudre un problème par la recherche, tant à l’oral (présentation en binôme ou en groupe) qu’à l’écrit (rapport\\xa0de\\xa0projet)']\n        ",
# 'aperçu': "Le cours « Résolution de problèmes par la recherche », destiné à des étudiants de Licence 3 en Intelligence Artificielle, vise à les rendre capables de résoudre des problèmes par la recherche en appliquant des méthodes scientifiques rigoureuses. L’objectif général est clairement défini et les objectifs spécifiques sont bien alignés avec le niveau d'étude et le contenu du cours.\n\nLes objectifs spécifiques sont globalement bien formulés, avec une bonne mesurabilité et une adéquation pertinente au public cible. Cependant, certaines recommandations soulignent la nécessité de préciser davantage les types de problèmes et les méthodes scientifiques à appliquer, ainsi que les ressources disponibles, comme les outils ou les logiciels à utiliser. Par exemple, il est suggéré de mentionner explicitement les outils statistiques comme R et SPSS pour l'analyse des résultats de recherche.\n\nEn résumé, bien que les objectifs soient bien définis et mesurables, des ajustements mineurs pourraient les rendre encore plus spécifiques et réalistes, en intégrant des informations supplémentaires sur les ressources et les contextes d'application.",
# 'details': '\n
# #### Objectif général :\nÀ l’issue de l’unité d’enseignement, les étudiants seront capables de résoudre des problèmes par la recherche en appliquant des méthodes scientifiques rigoureuses.\n\n
# - **Niveau** : Application\n- **Spécifique** : L\'objectif est clair et précis, mais il pourrait être encore plus spécifique en définissant les types de problèmes et les méthodes scientifiques à appliquer. Note : **4/5**\n- **Mesurable** : L\'objectif utilise un verbe d\'action observable ("résoudre") et précise le type de résultat attendu ("problèmes par la recherche"). Note : **5/5**\n- **Approprié (Cohérent)** : Cet objectif est pertinent pour des étudiants en Licence 3 en IA, car il est aligné avec le niveau d\'étude et le contenu du cours. Note : **5/5**\n- **Réaliste** : L\'objectif semble réalisable dans le cadre d\'une unité d\'enseignement, mais il manque des informations sur les ressources disponibles, comme les outils ou les logiciels à utiliser. Note : **4/5**\n- **Temporellement défini** : L\'objectif est bien défini temporellement ("À l’issue de l’unité d’enseignement"). Note : **5/5**\n\n**Recommandation(s) :**\n- **Spécifique** : Préciser les types de problèmes et les méthodes scientifiques à appliquer. Par exemple, "À l’issue de l’unité d’enseignement, les étudiants seront capables de résoudre des problèmes de classification en utilisant des méthodes statistiques et des algorithmes d\'apprentissage supervisé."\n- **Réaliste** : Ajouter des informations sur les ressources disponibles, comme les outils ou les logiciels à utiliser. Par exemple, "À l’issue de l’unité d’enseignement, les étudiants seront capables de résoudre des problèmes de classification en utilisant des méthodes statistiques et des algorithmes d\'apprentissage supervisé avec des outils comme Python et R."\n\n
# #### Objectifs spécifiques\n\n
# **Objectif 1** : À l’issue de l’unité d’enseignement, les étudiants seront capables de formuler des hypothèses de recherche pertinentes en utilisant des données empiriques.\n\n
# - **Niveau** : Application\n- **Spécifique** : L\'objectif est clair et précis, mais il pourrait être encore plus spécifique en définissant le type de données empiriques et le contexte d\'application. Par exemple, préciser si les données sont quantitatives ou qualitatives et dans quel cadre elles seront utilisées. Note : **4/5**\n- **Mesurable** : L\'objectif utilise un verbe d\'action observable ("formuler") et précise le type de résultat attendu ("hypothèses de recherche pertinentes"). Note : **5/5**\n- **Approprié (Cohérent)** : Cet objectif est pertinent pour des étudiants en Licence 3 en IA, car il est aligné avec le niveau d\'étude et le contenu du cours. Note : **5/5**\n- **Réaliste** : L\'objectif semble réalisable dans le cadre d\'une unité d\'enseignement, mais il manque des informations sur les ressources disponibles, comme les outils ou les logiciels à utiliser. Note : **4/5**\n- **Temporellement défini** : L\'objectif est bien défini temporellement ("À l’issue de l’unité d’enseignement"). Note : **5/5**\n\n**Recommandation(s) :**\n- **Spécifique** : Préciser le type de données empiriques et le contexte d\'application. Par exemple, "À l’issue de l’unité d’enseignement, les étudiants seront capables de formuler des hypothèses de recherche pertinentes en utilisant des données quantitatives dans le cadre de l\'analyse de données de santé."\n- **Réaliste** : Ajouter des informations sur les ressources disponibles, comme les outils ou les logiciels à utiliser. Par exemple, "À l’issue de l’unité d’enseignement, les étudiants seront capables de formuler des hypothèses de recherche pertinentes en utilisant des données quantitatives dans le cadre de l\'analyse de données de santé avec des outils comme Excel et SPSS."\n\n
# **Objectif 2** : Au terme de l’activité d’apprentissage, les étudiants seront capables de concevoir un plan de recherche détaillé en respectant les normes méthodologiques.\n\n- **Niveau** : Application\n- **Spécifique** : L\'objectif est spécifique et précis, mais il pourrait être encore plus détaillé en mentionnant les normes méthodologiques spécifiques à respecter, par exemple, les standards de l\'APA ou les directives de l\'université. Note : **4/5**\n- **Mesurable** : L\'objectif utilise un verbe d\'action observable ("concevoir") et précise le type de résultat attendu ("plan de recherche détaillé"). Note : **5/5**\n- **Approprié (Cohérent)** : Cet objectif est pertinent pour des étudiants en Licence 3 en IA, car il est aligné avec le niveau d\'étude et le contenu du cours. Note : **5/5**\n- **Réaliste** : L\'objectif semble réalisable dans le cadre d\'une activité d\'apprentissage, mais il manque des informations sur les ressources disponibles, comme les outils de planification ou les guides méthodologiques. Note : **4/5**\n- **Temporellement défini** : L\'objectif est bien défini temporellement ("Au terme de l’activité d’apprentissage"). Note : **5/5**\n\n**Recommandation(s) :**\n- **Spécifique** : Mentionner les normes méthodologiques spécifiques à respecter. Par exemple, "Au terme de l’activité d’apprentissage, les étudiants seront capables de concevoir un plan de recherche détaillé en respectant les standards de l\'APA."\n- **Réaliste** : Ajouter des informations sur les ressources disponibles, comme les outils de planification ou les guides méthodologiques. Par exemple, "Au terme de l’activité d’apprentissage, les étudiants seront capables de concevoir un plan de recherche détaillé en respectant les standards de l\'APA en utilisant des guides méthodologiques et des outils de planification comme Trello."\n\n**Objectif 3** : À la fin du cours, les étudiants seront capables d’analyser des résultats de recherche en utilisant des outils statistiques appropriés.\n\n- **Niveau** : Analyse\n- **Spécifique** : L\'objectif est spécifique et précis, mais il pourrait être encore plus détaillé en mentionnant les outils statistiques spécifiques à utiliser, par exemple, SPSS, R, ou Excel. Note : **4/5**\n- **Mesurable** : L\'objectif utilise un verbe d\'action observable ("analyser") et précise le type de résultat attendu ("résultats de recherche"). Note : **5/5**\n- **Approprié (Cohérent)** : Cet objectif est pertinent pour des étudiants en Licence 3 en IA, car il est aligné avec le niveau d\'étude et le contenu du cours. Note : **5/5**\n- **Réaliste** : L\'objectif semble réalisable dans le cadre d\'un cours, mais il manque des informations sur les ressources disponibles, comme les logiciels statistiques ou les bases de données. Note : **4/5**\n- **Temporellement défini** : L\'objectif est bien défini temporellement ("À la fin du cours"). Note : **5/5**\n\n**Recommandation(s) :**\n- **Spécifique** : Mentionner les outils statistiques spécifiques à utiliser. Par exemple, "À la fin du cours, les étudiants seront capables d’analyser des résultats de recherche en utilisant des outils statistiques appropriés comme R et SPSS."\n- **Réaliste** : Ajouter des informations sur les ressources disponibles, comme les logiciels statistiques ou les bases de données. Par exemple, "À la fin du cours, les étudiants seront capables d’analyser des résultats de recherche en utilisant des outils statistiques appropriés comme R et SPSS, avec l\'accès à des bases de données pertinentes."\n\n**Objectif 4** : À l’issue de l’unité d’enseignement, les étudiants seront capables de rédiger un rapport de recherche en suivant les normes académiques.\n\n- **Niveau** : Application\n- **Spécifique** : L\'objectif est spécifique et précis, mais il pourrait être encore plus détaillé en mentionnant les normes académiques spécifiques à suivre, par exemple, les standards de l\'APA ou les directives de l\'université. Note : **4/5**\n- **Mesurable** : L\'objectif utilise un verbe d\'action observable ("rédiger") et précise le type de résultat attendu ("rapport de recherche"). Note : **5/5**\n- **Approprié (Cohérent)** : Cet objectif est pertinent pour des étudiants en Licence 3 en IA, car il est aligné avec le niveau d\'étude et le contenu du cours. Note : **5/5**\n- **Réaliste** : L\'objectif semble réalisable dans le cadre d\'une unité d\'enseignement, mais il manque des informations sur les ressources disponibles, comme les guides de rédaction ou les modèles de rapport. Note : **4/5**\n- **Temporellement défini** : L\'objectif est bien défini temporellement ("À l’issue de l’unité d’enseignement"). Note : **5/5**\n\n**Recommandation(s) :**\n- **Spécifique** : Mentionner les normes académiques spécifiques à suivre. Par exemple, "À l’issue de l’unité d’enseignement, les étudiants seront capables de rédiger un rapport de recherche en suivant les standards de l\'APA."\n- **Réaliste** : Ajouter des informations sur les ressources disponibles, comme les guides de rédaction ou les modèles de rapport. Par exemple, "À l’issue de l’unité d’enseignement, les étudiants seront capables de rédiger un rapport de recherche en suivant les standards de l\'APA, en utilisant des guides de rédaction et des modèles de rapport fournis."\n\n**Complétude**\nL\'ensemble des objectifs spécifiques couvre bien les différentes étapes de la résolution de problèmes par la recherche : formulation d\'hypothèses, conception de plans de recherche, analyse des résultats et rédaction de rapports. Ces objectifs permettent de réaliser l\'objectif global/général du cours. Note : **5/5**\n\n### Résumé\n- **Objectif 1** : Spécifique (4/5), Mesurable (5/5), Approprié (Cohérent) (5/5), Réaliste (4/5), Temporellement défini (5/5)\n- **Objectif 2** : Spécifique (4/5), Mesurable (5/5), Approprié (Cohérent) (5/5), Réaliste (4/5), Temporellement défini (5/5)\n- **Objectif 3** : Spécifique (4/5), Mesurable (5/5), Approprié (Cohérent) (5/5), Réaliste (4/5), Temporellement défini (5/5)\n- **Objectif 4** : Spécifique (4/5), Mesurable (5/5), Approprié (Cohérent) (5/5), Réaliste (4/5), Temporellement défini (5/5)\n- **Complétude** : 5/5\n      '}

# %%
rapport['details']
# Out:
# '\n      #### Objectif général :\nLes étudiants seront capables de maîtriser les méthodes d\'analyse et de spécification des systèmes d\'information, en identifiant et formalisant les besoins utilisateurs, en modélisant des systèmes d\'information avec UML, en concevant des architectures logicielles, en validant les modèles produits, en implémentant des prototypes fonctionnels, en collaborant efficacement en équipe, et en présentant oralement et par écrit les résultats d’analyse et de conception.\n\n- **Niveau : Évaluer**\n- **Spécifique :** L\'objectif est clair et précis, mais il pourrait être encore plus spécifique en mentionnant les techniques exactes à utiliser et les contextes d\'application. Note : **4/5**\n- **Mesurable :** Le verbe "maîtriser" est observable, mais il serait utile de préciser les critères de réussite pour chaque composante de l\'objectif. Note : **3/5**\n- **Approprié (Cohérent) :** Cet objectif est cohérent avec le niveau de Licence 3 et le public cible (étu
# ...

# %%
from features_api import recapitulatif

recap = recapitulatif(rapport['details'])
print(recap)
# Out:
# INFO:features_api:Appel de l'API Mistral...
# INFO:httpx:HTTP Request: POST https://api.mistral.ai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:features_api:Réponse reçue avec succès.
# ```python
# {
#     "points_forts": [
#         "Clarté des objectifs",
#         "Niveau de Bloom adéquat",
#         "Adéquation au contenu du cours",
#         "Réalisme des objectifs",
#         "Cohérence avec le niveau de Licence 3 et le public cible"
#     ],
#     "axes_amelioration": [
#         "Certains objectifs sont trop vagues",
#         "Certains verbes ne correspondent pas au niveau annoncé",
#         "Manque de définition temporelle claire",
#         "Manque de spécificité dans les techniques et contextes d'application",
#         "Manque de critères de réussite précis"
#     ],
#     "objectifs_total": 7,
#     "objectifs_conformes": {
#         "nbre_total": 0,
#         "liste": []
#     },
#     "objectifs_a_ameliorer": {
#         "nbre_total": 7,
#         "liste": [
# ...

# %%
import ast
import json
import re
import logging

# Configuration du logger
logger = logging.getLogger(__name__)

def llm_output_to_dict(llm_output):
    """
    Convertit une sortie de LLM en dictionnaire Python de manière robuste.
    
    Args:
        llm_output (str): La sortie du LLM contenant un dictionnaire
        
    Returns:
        dict: Le dictionnaire Python converti
        
    Raises:
        ValueError: Si la conversion échoue
    """
    logger.debug("Début de la conversion de la sortie LLM en dictionnaire")
    
    # Nettoyer la sortie (enlever les balises markdown si présentes)
    cleaned_output = llm_output.strip()
    logger.debug(f"Sortie nettoyée, longueur: {len(cleaned_output)} caractères")
    
    # Enlever les balises de code markdown si présentes
    if cleaned_output.startswith('```'):
        logger.debug("Détection de balises markdown, nettoyage en cours")
        lines = cleaned_output.split('\n')
        # Trouver la première ligne qui ne commence pas par ```
        start_idx = 1
        for i, line in enumerate(lines):
            if not line.strip().startswith('```') and not line.strip().startswith('python'):
                start_idx = i
                break
        
        # Trouver la dernière ligne qui ne finit pas par ```
        end_idx = len(lines) - 1
        for i in range(len(lines) - 1, -1, -1):
            if not lines[i].strip().endswith('```'):
                end_idx = i
                break
        
        cleaned_output = '\n'.join(lines[start_idx:end_idx + 1])
        logger.debug(f"Balises markdown supprimées, nouvelle longueur: {len(cleaned_output)} caractères")
    
    # Méthode 1: Essayer ast.literal_eval (plus sûr)
    try:
        logger.debug("Tentative de conversion avec ast.literal_eval")
        result = ast.literal_eval(cleaned_output)
        if isinstance(result, dict):
            logger.info("Conversion réussie avec ast.literal_eval")
            return result
    except (ValueError, SyntaxError) as e:
        logger.warning(f"ast.literal_eval a échoué: {e}")
    
    # Méthode 2: Essayer json.loads
    try:
        logger.debug("Tentative de conversion avec json.loads")
        result = json.loads(cleaned_output)
        if isinstance(result, dict):
            logger.info("Conversion réussie avec json.loads")
            return result
    except json.JSONDecodeError as e:
        logger.warning(f"json.loads a échoué: {e}")
    
    # Méthode 3: Essayer de corriger les erreurs JSON communes
    try:
        logger.debug("Tentative de correction JSON et conversion")
        # Remplacer les apostrophes simples par des guillemets doubles
        json_corrected = re.sub(r"'([^']*)':", r'"\1":', cleaned_output)
        json_corrected = re.sub(r":\s*'([^']*)'", r': "\1"', json_corrected)
        
        result = json.loads(json_corrected)
        if isinstance(result, dict):
            logger.info("Conversion réussie après correction JSON")
            return result
    except json.JSONDecodeError as e:
        logger.error(f"Correction JSON a échoué: {e}")
    
    # Si tout échoue, lever une exception
    logger.error("Toutes les méthodes de conversion ont échoué")
    raise ValueError("Impossible de convertir la sortie LLM en dictionnaire")

# Pour exécuter
recap_dict = llm_output_to_dict(recap)
logger.info("Type du récapitulatif: ", type(recap_dict))
# Out:
# INFO:__main__:Conversion réussie avec ast.literal_eval
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Sadi\miniconda3\Lib\logging\__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Sadi\miniconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Sadi\miniconda3\Lib\logging\__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Sadi\miniconda3\Lib\logging\__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
# ...

# %%
def build_tables_from_recap_dict(recap_dict):
    table_chif = [('Élément analysé ', 'Nombre')]
    table_chif.append(("Objectifs saisis", str(recap_dict.get('objectifs_total', 00))))
    table_chif.append(("Objectifs conformes", str(recap_dict.get('objectifs_conformes', {}).get('nbre_total', 00))))
    table_chif.append(("Objectifs à améliorer", str(recap_dict.get('objectifs_a_ameliorer', {}).get('nbre_total', 00))))
    table_chif.append(("Niveaux de Bloom représentés", str(recap_dict.get("niveaux_bloom_utilises", 00))))


    table_ameliorer = [('N°', 'Objectif', 'Problème', 'Suggestion')]
    objectifs_a_ameliorer = recap_dict.get('objectifs_a_ameliorer', {}).get('liste', [])
    if objectifs_a_ameliorer:
        for obj in objectifs_a_ameliorer:
            table_ameliorer.append((
                str(obj.get('num', '')),
                str(obj.get('objectif', '')),
                str(obj.get('probleme_resume', '')),
                str(obj.get('suggestion', ''))
            ))
    else:
        table_ameliorer.append(('', 'Aucun objectif à améliorer', '', ''))


    table_conformes = [('N°', 'Objectif', 'Niveau de Bloom')]
    objectifs_conformes = recap_dict.get('objectifs_conformes', {}).get('liste', [])
    if objectifs_conformes:
        for obj in objectifs_conformes:
            table_conformes.append((
                str(obj.get('num', '')),
                str(obj.get('objectif', '')),
                str(obj.get('niveau_bloom', ''))
            ))
    else:
        table_conformes.append(('', 'Aucun objectif conforme', ''))


    table_axes = [('Points forts', 'Axes d\'amélioration')]
    pf = recap_dict.get('points_forts', [])
    ax = recap_dict.get('axes_amelioration', [])
    if pf or ax:
        for i in range(max(len(pf), len(ax))):
            table_axes.append((pf[i] if i < len(pf) else '', ax[i] if i < len(ax) else ''))
    else:
        table_axes.append(('Aucun point fort identifié', 'Aucun axe d’amélioration identifié'))


    table_recom = [('N°', 'Recommandation clée')]
    recommandations = recap_dict.get('recommandations', [])
    if recommandations:
        for i, rec in enumerate(recommandations, 1):
            table_recom.append((str(i), rec))
    else:
        table_recom.append(('', 'Aucune recommandation'))

    return table_chif, table_axes, table_recom, table_ameliorer, table_conformes

# %%
from fpdf import FPDF
from IPython.display import display, FileLink
import re
from datetime import datetime

# LE BON
class PDF(FPDF):
    def __init__(self):
        super().__init__()
        self.add_font("DejaVu", "", "assets\\fonts\\DejaVu\\DejaVuSans.ttf", uni=True)
        self.add_font("DejaVu", "B", "assets\\fonts\\DejaVu\\DejaVuSans-Bold.ttf", uni=True)
        self.add_font("DejaVu", "I", "assets\\fonts\\DejaVu\\DejaVuSans-Oblique.ttf", uni=True)
        self.add_font("DejaVu", "BI", "assets\\fonts\\DejaVu\\DejaVuSans-BoldOblique.ttf", uni=True)

        self.title = ""
        self.current_chapter_title = ""
        self.is_chapter_start = False
        self.is_page_de_garde = False

        self.table_counter = 1
        

# Traitement du texte issu du llm

    def write_rich_line(self, text):
        parts = re.split(r'(\*\*.*?\*\*)', text)
        for part in parts:
            if part.startswith('**') and part.endswith('**'):
                self.set_font("DejaVu", "B", 10)
                self.write(8, part[2:-2])
            else:
                self.set_font("DejaVu", "", 10)
                self.write(8, part)
        self.ln()
        
    def write_markdown(self, md_text):
        lines = md_text.split('\n')
        for line in lines:
            self.set_text_color(0, 0, 0)
            line = line.strip()
            handled = False
            
            if line.startswith('**') and line.endswith('**'):
                #self.cell(3)
                self.set_text_color(25, 25, 112)
                
                
            # Cas combiné : bullet + texte enrichi (**...**)
            if (line.startswith('- ') or line.startswith('* ')) and '**' in line:
                self.set_font("DejaVu", "", 10)
                self.cell(3)  # indent
                line_content = u'\u2022 ' + line[2:].strip()
                self.write_rich_line(line_content)
                handled = True

            # Cas simple : bullet sans enrichissement
            elif line.startswith('- ') or line.startswith('* '):
                self.set_font("DejaVu", "", 10)
                self.cell(3)
                self.multi_cell(0, 7, u'\u2022 ' + line[2:], ln=True, align='J')
                handled = True

            # Titres Markdown
            elif line.startswith('# '):
                self.set_font("DejaVu", "B", 15)
                self.set_text_color(25, 25, 112)
                self.multi_cell(0, 7, line[2:], ln=True, align='J')
                handled = True
            elif line.startswith('## '):
                self.set_font("DejaVu", "B", 14)
                self.set_text_color(25, 25, 112)
                self.multi_cell(0, 7, line[3:], ln=True, align='J')
                handled = True
            elif line.startswith('### '):
                self.set_font("DejaVu", "B", 13)
                self.set_text_color(25, 25, 112)
                self.multi_cell(0, 7, line[4:], ln=True, align='J')
                handled = True
            elif line.startswith('#### '):
                self.set_font("DejaVu", "B", 12)
                self.set_text_color(25, 25, 112)
                self.multi_cell(0, 7, line[5:], ln=True, align='J')
                handled = True

            # Cas général avec gras partiel (hors bullets)
            elif '**' in line:
                self.write_rich_line(line)
                handled = True

            # Cas par défaut : texte normal
            if not handled:
                self.set_font("DejaVu", "", 10)
                #self.cell(3)
                self.multi_cell(0, 7, line, align='J')
                self.ln(0)


# Tableaux du chapitre Récapitulatif       
     
    def table_title(self, title):
        self.set_font("DejaVu", "BI", 10)
        self.set_text_color(80, 80, 80)
        self.cell(0, 6, f"Tableau {self.table_counter} : {title}", ln=True)
        self.ln(2)
        self.table_counter += 1

    def add_table_chiffres_cles(self, data):
        self.table_title("Les chiffres clés")
        self.set_font("DejaVu", "", 9)
        with self.table(width=180, col_widths=(100, 80)) as table:
            for row_data in data:
                row = table.row()
                for i, cell in enumerate(row_data):
                    row.cell(cell, border="BOTTOM", padding=(2, 1), align="LEFT")
                    
    def add_table_points_forts(self, data):
        self.table_title("Points forts et axes d'amélioration identifiés")
        self.set_font("DejaVu", "", 9)
        with self.table(width=180, borders_layout="MINIMAL") as table:
            for row_data in data:
                row = table.row()
                for cell in row_data:
                    row.cell(cell, padding=(1, 5, 1))

    def add_table_recommandations(self, data):
        self.table_title("Recommandations globales")
        self.set_font("DejaVu", "", 9)
        with self.table(width=180, col_widths=(15, 165)) as table:
            for row_data in data:
                row = table.row()
                for cell in row_data:
                    row.cell(cell, border="BOTTOM", padding=(1, 1))
                    
    def add_table_objectifs_a_ameliorer(self, data):
        self.table_title("Objectifs à améliorer")
        self.set_font("DejaVu", "", 9)
        with self.table(width=180, col_widths=(20, 70, 45, 45)) as table:
            for row_data in data:
                row = table.row()
                for cell in row_data:
                    # Réduction du padding pour moins d’espace vertical
                    row.cell(cell, padding=(1.5, 2, 1.5))
                    
    def add_table_objectifs_conformes(self, data):
        self.table_title("Objectifs satisfaisants")
        self.set_font("DejaVu", "", 9)
        with self.table(width=180) as table:
            for row_data in data:
                row = table.row()
                for cell in row_data:
                    # Réduction du padding pour moins d’espace vertical
                    row.cell(cell, padding=(1.5, 2, 1.5))
                    
                    
# Constitution du pdf

    def chapter_title(self, num, label):
        self.current_chapter_title = label
        self.set_y(30)

        self.set_fill_color(70, 130, 180)  # Badge vertical
        self.set_font("helvetica", "B", 14)
        self.cell(2, 18, "", fill=True, border=0)

        self.set_fill_color(250, 250, 250)
        self.set_text_color(25, 25, 112)
        self.set_draw_color(70, 130, 180)
        self.set_line_width(0.5)
        self.cell(
            0,
            18,
            f"   Chapitre {num} : {label}",
            border="B",
            ln=True,
            align="L",
            fill=True
        )
        self.ln(6)

    def header(self):
        if self.is_page_de_garde:
            return
        
        self.set_fill_color(245, 248, 255)
        self.rect(12, 9.5, 185, 9, 'F')

        self.set_font("helvetica", "B", 10)
        self.set_draw_color(70, 130, 180)
        
        # Position initiale de la marge
        left_margin = self.l_margin
        right_margin = self.w - self.r_margin

        #self.set_y(self.get_y() + 3)
        y = self.get_y()

        # Gauche : titre fixe
        self.set_xy(left_margin, y)
        self.set_text_color(90, 90, 90)
        self.cell(0, 8, "Analyse des objectifs pédagogiques", align='L')
        
        if getattr(self, "is_chapter_start", False):
            return
        
        # Droite : nom du chapitre (à partir du dernier titre connu)
        self.set_xy(right_margin - 70, y)  # Ajuste 70 selon la largeur du texte
        
        self.set_text_color(25, 25, 112)

        self.cell(
            70,
            8,
            f"Chapitre : {self.current_chapter_title}",
            border="B",
            ln=True,
            align="R"
        )
    
        self.ln(12)

    def footer(self):
        self.set_y(-15)
        self.set_font("helvetica", style="I", size=8)
        self.set_text_color(128)
        self.cell(0, 10, f"Page {self.page_no()}", align="C")

    def add_page_de_garde(self, titre, sous_titre, auteur=None, date=None):
        self.is_page_de_garde = True
        self.add_page()
        self.set_font("DejaVu", 'B', 20)

        # Titre principal centré
        self.ln(60)  # espace vers le bas
        self.set_text_color(25, 25, 112)
        self.multi_cell(0, 15, titre, ln=True, align='C')

        # Sous-titre
        self.set_font("DejaVu", '', 13)
        self.set_text_color(0, 0, 0)
        self.ln(10)
        self.multi_cell(0, 10, sous_titre, ln=True, align='C')

        # Auteur et date
        self.set_font("DejaVu", 'I', 12)
        self.set_text_color(100, 100, 100)
        if auteur:
            self.ln(40)
            self.cell(0, 10, f"Établi par : {auteur}", ln=True, align='C')
        if date:
            self.cell(0, 10, f"Date : {date}", ln=True, align='C')

    def add_recap_tables(self, table_chif, table_axes, table_recom, table_ameliorer, table_conformes):
        self.current_chapter_title = "Récapitulatif"
        self.is_page_de_garde = False
        self.is_chapter_start = True         
        self.add_page()
        self.chapter_title(4, "Récapitulatif")

        self.add_table_chiffres_cles(table_chif)
        self.ln(14)
        
        self.add_table_points_forts(table_axes)
        self.ln(14)

        self.add_table_recommandations(table_recom)
        self.ln(14)

        self.add_table_objectifs_a_ameliorer(table_ameliorer)
        self.ln(14)

        self.add_table_objectifs_conformes(table_conformes)

# Constitution du chapitre rappel infos cours
    def rappel_infos_cours(self, nom_cours, niveau, public, objectif_general, objectifs_specifiques_brut):
        self.current_chapter_title = "Rappel des informations de cours"
        self.is_page_de_garde = False
        self.is_chapter_start = True 
        self.add_page()
        self.chapter_title(1, "Rappel des informations de cours")
        
        # Cours
        self.set_font("DejaVu", "B", 10)
        self.write(8, "Cours :")
        self.set_font("DejaVu", "", 10)
        self.write(8, nom_cours)
        self.ln(8)
        
        # Niveau
        self.set_font("DejaVu", "B", 10)
        self.write(8, "Niveau :")
        self.set_font("DejaVu", "", 10)
        self.write(8, niveau)
        self.ln(8)
        
        # Public cible
        self.set_font("DejaVu", "B", 10)
        self.write(8, "Public cible :")
        self.set_font("DejaVu", "", 10)
        self.write(8, public)
        self.ln(8)
        
        # Objectif général 
        self.set_font("DejaVu", "B", 10)
        self.set_text_color(25, 25, 112)
        self.write(8, "Objectif général  :")
        
        self.ln()
        self.set_font("DejaVu", "", 10)
        self.set_text_color(0, 0, 0)
        self.cell(3)
        self.multi_cell(0, 7, objectif_general, align='J')
        self.ln(8)
        
        # Objectifs spécifiques 
        self.set_font("DejaVu", "B", 10)
        self.set_text_color(25, 25, 112)
        self.write(8, "Objectifs spécifiques  :")
        
        self.ln()
        self.set_font("DejaVu", "", 10)
        self.set_text_color(0, 0, 0)
        self.cell(3)
        self.multi_cell(0, 7, objectifs_specifiques_brut, align='J')


    def chapter_body(self, text):
        self.set_font("DejaVu", size=12)
        self.is_chapter_start = False  
        self.write_markdown(text)
        self.ln()
        self.set_font("DejaVu", "I", 10)
        #self.cell(0, 5, "(fin du chapitre)", ln=True)

    def print_chapter(self, num, title, text):
        self.current_chapter_title = title
        self.is_page_de_garde = False
        self.is_chapter_start = True  # Active la logique "pas de header"
        self.add_page()
        self.chapter_title(num, title)
        self.chapter_body(text)

pdf = PDF()
pdf.set_title("Analyse automatique des objectifs pédagogiques")
pdf.set_left_margin(15)
pdf.set_right_margin(15)

        
#pdf.set_author("ObjectifsAI")
pdf.add_page_de_garde(
    titre=f"Rapport d’analyse des objectifs pédagogiques du cours de {nom_cours}",
    sous_titre="Évaluation des objectifs pédagogique selon la taxonomie de Bloom et des critères SMART adaptés au contexte pédagogique",
    auteur="ObjectifsAI",
    date=datetime.now().strftime("%d %B %Y")
)

#pdf.print_chapter(1, "Rappel des informations de cours", rapport['informations_cours'])
pdf.rappel_infos_cours(nom_cours, niveau, public, objectif_general, objectifs_specifiques_brut)
pdf.print_chapter(2, "Aperçu global de l'analyse", rapport['aperçu'])
pdf.print_chapter(3, "Analyse détaillée", rapport['details'])

recap_dict = llm_output_to_dict(recap)
table_chif, table_axes, table_recom, table_ameliorer, table_conformes = build_tables_from_recap_dict(recap_dict)
pdf.add_recap_tables(table_chif, table_axes, table_recom, table_ameliorer, table_conformes)

pdf.output("preview.pdf")
display(FileLink("preview.pdf"))
# Out:
# C:\Users\Sadi\AppData\Local\Temp\ipykernel_1684\1005074932.py:9: DeprecationWarning: "uni" parameter is deprecated since v2.5.1, unused and will soon be removed
#   self.add_font("DejaVu", "", "assets\\fonts\\DejaVu\\DejaVuSans.ttf", uni=True)
# C:\Users\Sadi\AppData\Local\Temp\ipykernel_1684\1005074932.py:10: DeprecationWarning: "uni" parameter is deprecated since v2.5.1, unused and will soon be removed
#   self.add_font("DejaVu", "B", "assets\\fonts\\DejaVu\\DejaVuSans-Bold.ttf", uni=True)
# C:\Users\Sadi\AppData\Local\Temp\ipykernel_1684\1005074932.py:11: DeprecationWarning: "uni" parameter is deprecated since v2.5.1, unused and will soon be removed
#   self.add_font("DejaVu", "I", "assets\\fonts\\DejaVu\\DejaVuSans-Oblique.ttf", uni=True)
# C:\Users\Sadi\AppData\Local\Temp\ipykernel_1684\1005074932.py:12: DeprecationWarning: "uni" parameter is deprecated since v2.5.1, unused and will soon be removed
# ...

# %% [markdown]
# ### FIN

# %%
print(recap_dict)
# Out:
# {'points_forts': ['Clarté des objectifs', 'Niveau de Bloom adéquat', 'Adéquation au contenu du cours', 'Réalisme des objectifs', 'Cohérence avec le niveau de Licence 3 et le public cible'], 'axes_amelioration': ['Certains objectifs sont trop vagues', 'Certains verbes ne correspondent pas au niveau annoncé', 'Manque de définition temporelle claire', "Manque de spécificité dans les techniques et contextes d'application", 'Manque de critères de réussite précis'], 'objectifs_total': 7, 'objectifs_conformes': {'nbre_total': 0, 'liste': []}, 'objectifs_a_ameliorer': {'nbre_total': 7, 'liste': [{'num': 1, 'objectif': 'Identifier et formaliser les besoins utilisateurs à l’aide de techniques.', 'probleme_resume': 'Manque de spécificité dans les techniques et de critères de réussite précis', 'suggestion': 'Mentionner les techniques exactes à utiliser et préciser les critères de réussite.'}, {'num': 2, 'objectif': 'Modéliser des systèmes d’information avec UML (Diagrammes de cas d’utilisation, 
# ...

# %% [markdown]
# recap_dict =
#
# {'points_forts': ['Les objectifs sont clairs et précis.', "Les objectifs utilisent des verbes d'action observables.", "Les objectifs sont pertinents pour le niveau d'étude et le public cible.", 'Les objectifs sont réalisables dans le temps imparti.', 'Les objectifs ont un échéancier clair.'],
#
# 'axes_amelioration': ['Certains objectifs sont trop vagues et manquent de contextes spécifiques.', 'Il manque des critères de mesure précis.', "Les objectifs pourraient être mieux alignés avec l'objectif général.", 'Il manque de détails sur les ressources disponibles.', 'Il pourrait inclure des jalons intermédiaires.'],
#
# 'objectifs_total': 4,
#
# 'objectifs_conformes': {
#     'nbre_total': 0,
#     'liste': []},
#
# 'objectifs_a_ameliorer': {
#     'nbre_total': 4,
#     'liste': [
#         {'num': 'Objectif général',
#         'objectif': 'À l’issue de l’unité d’enseignement, l’apprenant·e sera capable de concevoir et de formaliser des modèles d’analyse et de spécification pour des systèmes d’intelligence artificielle en utilisant des outils et des techniques appropriés.',
#         'probleme_resume': 'Manque de spécificité, de mesurabilité, de réalisme et de jalons intermédiaires.',
#         'suggestion': "Préciser les contextes et les conditions spécifiques d'application, ajouter des critères de mesure précis, inclure des jalons intermédiaires."},
#         {'num': 1,
#         'objectif': 'À l’issue de la séance, l’apprenant·e sera capable de définir les concepts clés de l’analyse et de la spécification des systèmes d’intelligence artificielle en utilisant des termes techniques appropriés.',
#         'probleme_resume': 'Manque de spécificité, de mesurabilité, de réalisme et de jalons intermédiaires.',
#         'suggestion': "Préciser les contextes et les conditions spécifiques d'application, ajouter des critères de mesure précis, inclure des jalons intermédiaires."},
#         {'num': 2, 'objectif': 'À la fin du TP, l’apprenant·e sera capable d’appliquer les techniques d’analyse et de spécification pour modéliser un système d’intelligence artificielle en utilisant des outils logiciels spécifiques.', 'probleme_resume': 'Manque de spécificité, de mesurabilité, de réalisme et de jalons intermédiaires.', 'suggestion': "Préciser les contextes et les conditions spécifiques d'application, ajouter des critères de mesure précis, inclure des jalons intermédiaires."}, {'num': 3, 'objectif': 'À l’issue de l’unité d’enseignement, l’apprenant·e sera capable d’évaluer la qualité des modèles d’analyse et de spécification en utilisant des critères prédéfinis.', 'probleme_resume': 'Manque de spécificité, de mesurabilité, de réalisme et de jalons intermédiaires.', 'suggestion': "Préciser les contextes et les conditions spécifiques d'application, ajouter des critères de mesure précis, inclure des jalons intermédiaires."}]},
#
# 'recommandations': ["Préciser les contextes et les conditions spécifiques d'application.", 'Ajouter des critères de mesure précis.', 'Inclure des jalons intermédiaires.', "Aligner les objectifs spécifiques avec l'objectif général.", 'Définir les ressources disponibles pour atteindre les objectifs.'],
# 'niveaux_bloom_utilises': []}
